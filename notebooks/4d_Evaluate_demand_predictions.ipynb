# %% [markdown]
# # 4d. Evaluate demand predictions
#
# In the 3x_ notebooks, I evaluated individual model components in isolation (group snapshots in 3b, bed demand by service in 3d, yet-to-arrive demand in 3f). This notebook shows the `patientflow.evaluate`. At UCLH we use it to describe what to measure with `EvaluationTarget` rows, assemble data with `EvaluationInputsBuilder` (including a single `FlowSelection` for the run), then call `run_evaluation` to write charts plus `scalars.json` under a timestamped directory.
#
# A runner dispatches evaluation activity in five `evaluation_mode` scenarios. Classifier evaluation is split into **model-level diagnostics** (`classifier_model_diagnostics`, A) and **flow-level probability quality** (`classifier_probability_quality`, B: discrimination, MADCAP, and calibration on all test visits). Bed-demand PMF quality uses **`distribution`** (C). Yet-to-arrive rate diagnostics use **`arrival_deltas`**. A single global **`survival_curve`** target is optional (not shown here).
#
# ### How the `evaluate` package is designed
#
# Three objects carry the design:
#
# - **`EvaluationTarget`** — One row for each thing to be evaluated: it names which **runner branch** to use (`evaluation_mode`), how outputs should be **grouped and labelled** (`flow_name`, `name`, `flow_type`, `component`), and which **observation strategy** pairs with predicted distributions (`observation_mode`). See the table below for more detail.
# - **`EvaluationInputsBuilder` → `EvaluationInputs`** — The builder is a **mutable staging area**: you set `flow_selection`, `prediction_times`, and `evaluation_targets`, then call `add_classifier`, `add_distributions_*`, `add_arrival_deltas`, and so on. **`build()`** returns an **`EvaluationInputs`** instance: an **immutable** bundle of all registered tables and dicts the runner reads (classifier blocks, distribution blocks, arrival blocks, observation contexts, optional survival).
# - **`run_evaluation`** — Takes an output root plus **`EvaluationInputs`**, walks through the **`inputs.evaluation_targets`**, and **dispatches each target by `evaluation_mode`** to the right handler (plots under `classifiers/`, `distributions/`, `arrivals/`, … and scalar rows in `scalars.json`).
#
# The components of an EvaluationTarget are shown below.
#
# | `EvaluationTarget` field | Role |
# |---------------------------|------|
# | `flow_name` | Must match the `flow_name` passed to the corresponding **`add_*`** call so the target receives the right data block. |
# | `name` | Stable identifier for this target within its flow (outputs and sanity checks). |
# | `flow_type` | Logical pathway label for scalars and reporting (for example admissions vs departures). |
# | `evaluation_mode` | Selects the **handler**: `classifier_model_diagnostics`, `classifier_probability_quality`, `distribution`, `arrival_deltas`, or `survival_curve`. |
# | `component` | Distinguishes chart or scalar **families** at the same clock and service (for example `epudd`, `madcap`). |
# | `observation_mode` | Names the `count_observed` strategy in `patientflow.evaluate.observations`; used when distribution evaluation recomputes observed counts from builder frames. |
#
# ## Approach
#
# In this notebook I show the following:
#
# 1. **Load data** — same pattern as notebook 4c: `prepare_prediction_inputs`, temporal splits, synthetic ward `departure_datetime` for inpatient rows used with yet-to-arrive counting.
# 2. **Build prediction dictionaries** — `get_prob_dist_by_service` (ED current only) and the incoming-admission model for ED yet-to-arrive with `prediction_date` per test snapshot for weekday-aware rates
# 3. **Build inputs** — `EvaluationInputsBuilder` with `flow_selection`, `prediction_times`, and a custom `evaluation_targets` list whose `flow_name` keys match `add_classifier` / `add_distributions_*` / `add_arrival_deltas`. Distribution targets pair `add_distributions_from_service_dict` with `add_distribution_observations`. For arrival deltas with a multi-service predictor, pass `predictors_by_service` and `filter_keys_by_service` so the baseline matches each service.
# 4. **Run** — `run_evaluation(output_root, inputs, run_name=...)`.
# 5. **Inspect** — load `evaluation_rows` from `scalars.json` (and optional `_service_summary`).

# %%
# Reload functions every time
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Load data and train models
#
# The data loading and configuration steps match notebook 4c. Here `prepare_prediction_inputs` performs training and assembly in one call.
#
# You can request the UCLH datasets on [Zenodo](https://zenodo.org/records/14866057). If you do not have the public data, set `data_folder_name` to `'data-synthetic'`.

# %%
from patientflow.train.emergency_demand import prepare_prediction_inputs
from patientflow.prepare import create_temporal_splits
from patientflow.load import get_model_key
from datetime import timedelta
import numpy as np
import pandas as pd

data_folder_name = "data-public"
prediction_inputs = prepare_prediction_inputs(data_folder_name, verbose=False)

admissions_models = prediction_inputs["admission_models"]
spec_model = prediction_inputs["specialty_model"]
yta_model_by_spec = prediction_inputs["yta_model"]
ed_visits = prediction_inputs["ed_visits"]
inpatient_arrivals = prediction_inputs["inpatient_arrivals"]
params = prediction_inputs["config"]
model_name = "admissions"

x1, y1, x2, y2 = params["x1"], params["y1"], params["x2"], params["y2"]
prediction_window = timedelta(minutes=params["prediction_window"])
yta_time_interval = timedelta(minutes=params["yta_time_interval"])
prediction_times = params["prediction_times"]

start_training_set = params["start_training_set"]
start_validation_set = params["start_validation_set"]
start_test_set = params["start_test_set"]
end_test_set = params["end_test_set"]

_, _, test_visits_df = create_temporal_splits(
    ed_visits,
    start_training_set,
    start_validation_set,
    start_test_set,
    end_test_set,
    col_name="snapshot_date",
    visit_col="visit_number",
    verbose=False,
)

inpatient_arrivals = inpatient_arrivals.copy()
inpatient_arrivals["arrival_datetime"] = pd.to_datetime(
    inpatient_arrivals["arrival_datetime"], utc=True
)
_, _, test_inpatient_arrivals_df = create_temporal_splits(
    inpatient_arrivals,
    start_training_set,
    start_validation_set,
    start_test_set,
    end_test_set,
    col_name="arrival_datetime",
    verbose=False,
)

# Synthetic ward-admission timestamps for notebook demonstrations (see 4c).
np_rng = np.random.default_rng(42)
ward_delay_hours = np_rng.gamma(shape=4.0, scale=1.5, size=len(test_inpatient_arrivals_df))
ward_delay_hours = ward_delay_hours.clip(min=0.25)

test_inpatient_arrivals_df = test_inpatient_arrivals_df.copy()
test_inpatient_arrivals_df["departure_datetime"] = (
    test_inpatient_arrivals_df["arrival_datetime"]
    + pd.to_timedelta(ward_delay_hours, unit="h")
)

specialties = ["medical", "surgical", "haem/onc", "paediatric"]

# %% [markdown]
# ## 2. Build prediction dictionaries
#
# `get_prob_dist_by_service` returns, for each service, a snapshot date mapped to a 'leaf' that contains `agg_predicted` and `agg_observed` arrays for one `prediction_time` and one `flow_selection`. For aggregate predictions we need a distinct PMF for each prediction time and snapshot date: the pattern below nests predictions as `service → get_model_key(...) → date → leaf`.
#
# ED current and ED yet-to-arrive use different `FlowSelection` flags when calling `get_prob_dist_by_service`; the **evaluation run** still carries one combined `FlowSelection` on `EvaluationInputs` (here: current + ED yet-to-arrive only). `evaluation_run.yaml` snapshots project `config.yaml` (training dates, etc.) plus evaluation-only settings for this run.
#
# For ED yet-to-arrive PMFs, the code loops `snapshot_date` over the test calendar days and calls `yta_model_by_spec.predict(..., prediction_date=snapshot_date)`, matching weekday-stratified arrival profiles to that day.

# %%
from patientflow.aggregate import get_prob_dist_by_service
from patientflow.model_artifacts import ServiceModels
from patientflow.predict.demand import FlowSelection

test_snapshot_dates = [
    d.date() for d in pd.date_range(start_test_set, end_test_set, freq="D", inclusive="left")
]
print(f"Test set covers {len(test_snapshot_dates)} dates ({start_test_set} to {end_test_set})")

flow_sel_ed_current = FlowSelection.custom(
    include_ed_current=True,
    include_ed_yta=False,
    include_non_ed_yta=False,
    include_elective_yta=False,
    include_transfers_in=False,
    include_departures=False,
)

# Per service: model_key -> snapshot_date -> leaf (distinct PMF per prediction_time)
ed_current_by_service = {svc: {} for svc in specialties}
ed_yta_by_service = {svc: {} for svc in specialties}

for prediction_time in prediction_times:
    model_key = get_model_key(model_name, prediction_time)
    admission_model = admissions_models[model_key]
    service_models = ServiceModels(
        prediction_time=prediction_time,
        prediction_window=prediction_window,
        ed_classifier=admission_model,
        inpatient_classifier=None,
        spec_model=spec_model,
        ed_yta_model=yta_model_by_spec,
        non_ed_yta_model=None,
        elective_yta_model=None,
        transfer_model=None,
    )

    ed_current_probability_distributions_by_specialty = get_prob_dist_by_service(
        ed_visits,
        test_snapshot_dates,
        prediction_time,
        service_models,
        specialties,
        prediction_window,
        flow_selection=flow_sel_ed_current,
        x1=x1,
        y1=y1,
        x2=x2,
        y2=y2,
        component="arrivals",
        verbose=False,
    )
    for specialty in specialties:
        ed_current_by_service[specialty][model_key] = (
            ed_current_probability_distributions_by_specialty[specialty]
        )

    for specialty in specialties:
        yet_to_arrive_leaf_by_snapshot_date = {}
        for snapshot_date in test_snapshot_dates:
            if specialty in yta_model_by_spec.filters:
                yet_to_arrive_prediction_frame = yta_model_by_spec.predict(
                    prediction_time=prediction_time,
                    prediction_window=prediction_window,
                    filter_keys=specialty,
                    prediction_date=snapshot_date,
                    x1=x1,
                    y1=y1,
                    x2=x2,
                    y2=y2,
                )[specialty]
                predicted_probability_mass = yet_to_arrive_prediction_frame[
                    "agg_proba"
                ].copy(deep=True)
            else:
                predicted_probability_mass = pd.Series(
                    [1.0], index=[0], name="agg_proba"
                )
            yet_to_arrive_leaf_by_snapshot_date[snapshot_date] = {
                "agg_predicted": predicted_probability_mass,
                "agg_observed": 0,
            }
        ed_yta_by_service[specialty][model_key] = yet_to_arrive_leaf_by_snapshot_date

number_of_prediction_times = len(prediction_times)
number_of_specialties = len(specialties)
print(
    "Built nested distribution dictionaries:\n"
    f"  • {number_of_prediction_times} prediction times (one model_key per time-of-day).\n"
    f"  • {number_of_specialties} specialties.\n"
)
# Out:
# Test set covers 92 dates (2031-10-01 to 2032-01-01)
# Built nested distribution dictionaries:
#   • 5 prediction times (one model_key per time-of-day).
#   • 4 specialties.

# %% [markdown]
# ## 3. Prepare evaluation inputs
#
# The cells below step through the same workflow: import the builder types, prepare per-service tables the arrival handler needs, declare **`EvaluationTarget`** rows (each names an `evaluation_mode` and links to builder data via **`flow_name`**), then call the builder’s **`add_*`** methods in the same order you would reason about the pipeline. Finally **`build()`** returns immutable **`EvaluationInputs`** for **`run_evaluation`**.
#
# The default target registry (`get_default_evaluation_targets()` in `patientflow.evaluate.targets`) uses **`flow_name="main"`** for every row; this notebook uses several **`flow_name`** keys so ED classifiers, ED-current beds, ED YTA beds, and ED YTA arrival deltas stay clearly separated in outputs and in **`scalars.json`**.

# %% [markdown]
# ### 2a. Imports and default registry
#
# Import **`EvaluationInputsBuilder`** and **`EvaluationTarget`**, and optionally inspect how many rows the packaged default target list contains. You will replace that list with a custom one matched to this notebook’s **`flow_name`** keys.

# %%
from pathlib import Path

from patientflow.evaluate.inputs import EvaluationInputsBuilder, EvaluationTarget
from patientflow.evaluate.targets import get_default_evaluation_targets

print("Default registry size:", len(get_default_evaluation_targets()))
# Out:
# Default registry size: 8

# %% [markdown]
# ### 2b. Per-service inpatient arrivals for yet-to-arrive paths
#
# **`add_arrival_deltas`** (and the **`obs_ed_yta_by_service`** tables for **`ed_yta_beds`**) need inpatient arrival rows filtered the same way the yet-to-arrive model was trained. Here we reuse each service’s filter definition from **`yta_model_by_spec.filters`**.

# %%
arrivals_by_service = {}
for service, service_filters in yta_model_by_spec.filters.items():
    arrivals_by_service[service] = yta_model_by_spec.filter_dataframe(
        test_inpatient_arrivals_df, service_filters
    )

# %% [markdown]
# ### 2c. Declare `EvaluationTarget` rows
#
# Each target picks a runner branch via **`evaluation_mode`**: model-level classifier diagnostics (**A**), flow-level probability quality (**B**: discrimination, MADCAP, and calibration), bed-demand **distribution** (**C**), or **arrival_deltas**. **`observation_mode`** names the **`count_observed`** strategy that *should* pair with that target once distribution evaluation recomputes observed counts from the builder frames (see `patientflow.evaluate.observations`); today EPUDD still reads **`agg_observed`** already stored on each leaf. **`flow_name`** must match the string passed to the corresponding **`add_*`** calls below. Two classifier targets intentionally share **`flow_name="ed_admissions_cls"`** because they use the same trained models and visit frame. For **ED yet-to-arrive** distribution we use **`arrived_in_window`** with inpatient observation tables registered here so **`count_observed`** can treat them as **`visits`** (non-ED arrival-in-window semantics).

# %%
evaluation_targets = [
    # (A) Model-level classifier diagnostics: headline metrics and plots for each trained
    # admissions model (not repeated per hospital service).
    EvaluationTarget(
        flow_name="ed_admissions_cls",
        name="admission_classifier_model",
        flow_type="admissions",
        evaluation_mode="classifier_model_diagnostics",
        component="model_diagnostics",
        observation_mode="admitted_at_some_point",
    ),
    # (B) Service-level probability quality: MADCAP, discrimination, and calibration on ED visits,
    # Discrimination, MADCAP, and calibration on the full test visit frame (same classifiers as A).
    EvaluationTarget(
        flow_name="ed_admissions_cls",
        name="admission_classifier_prob",
        flow_type="admissions",
        evaluation_mode="classifier_probability_quality",
        component="madcap_calibration",
        observation_mode="admitted_at_some_point",
    ),
    # (C) Aggregate bed-demand PMF vs counts: composed ED-current predictions (EPUDD),
    # with observation_mode labelling the counting rule for ED snapshot admissions at some point.
    EvaluationTarget(
        flow_name="ed_current_beds",
        name="ed_current_epudd",
        flow_type="admissions",
        evaluation_mode="distribution",
        component="epudd",
        observation_mode="admitted_at_some_point",
    ),
    # (C) ED yet-to-arrive PMFs (section 1) for EPUDD. observation_mode="arrived_in_window" matches
    # count_observed's generic arrivals rule: inpatient arrival_datetime in (moment, moment+window],
    # using the per-service inpatient frames from add_distribution_observations as visits (not ed_visits).
    # Rows should be admitted inpatients only. EPUDD still reads leaf agg_observed until recomputation is wired.
    EvaluationTarget(
        flow_name="ed_yta_beds",
        name="ed_yta_epudd",
        flow_type="admissions",
        evaluation_mode="distribution",
        component="epudd",
        observation_mode="arrived_in_window",
    ),
    # Cumulative arrival-time diagnostics: observed vs expected admission timing in the window,
    # one PNG per (service, prediction_time); uses the arrival-deltas handler (not count_observed).
    EvaluationTarget(
        flow_name="ed_yta_arrival_rates",
        name="ed_yta_arrival_deltas",
        flow_type="admissions",
        evaluation_mode="arrival_deltas",
        component="cumulative_arrival_delta",
        observation_mode="arrived_in_window",
    ),
]

# %% [markdown]
# ### 2d. `FlowSelection` and start the builder
#
# **`EvaluationInputs`** carries exactly **one** **`FlowSelection`** for the run (written to **`evaluation_run.yaml`**). It should reflect the scenario you want to document alongside this evaluation, even when individual prediction dicts were built with narrower selections in section 1. Here we enable ED current and ED yet-to-arrive only.
#
# The builder also needs the global **`prediction_times`** list before any **`add_*`** call. We attach the target list with **`with_evaluation_targets`**.

# %%
eval_flow_selection = FlowSelection.custom(
    include_ed_current=True,
    include_ed_yta=True,
    include_non_ed_yta=False,
    include_elective_yta=False,
    include_transfers_in=False,
    include_departures=False,
)

builder = EvaluationInputsBuilder(
    flow_selection=eval_flow_selection,
    prediction_times=prediction_times,
).with_evaluation_targets(evaluation_targets)

# %% [markdown]
# ### 2e. Admission classifiers (A and B)
#
# **`add_classifier`** registers the trained models per prediction time and the ED test visits used for discrimination, MADCAP, calibration, and SHAP. Target **(B)** writes **`discrimination.png`**, **`madcap.png`**, **`madcap_by_age.png`**, and **`calibration.png`** under **`classifiers/<flow_name>/`** (alongside feature and SHAP outputs from **(A)**). The **`flow_name`** argument must match the classifier targets’ **`flow_name`** (`ed_admissions_cls`).

# %%
builder.add_classifier(
    "ed_admissions_cls",
    trained_models=admissions_models,
    visits_df=test_visits_df,
    label_col="is_admitted",
)

# %% [markdown]
# ### 2f. ED current bed demand (distribution, C)
#
# Register the nested PMFs from section 1, then attach **observation** frames: one ED visits dataframe per service (here the same **`test_visits_df`** for each). **`add_distribution_observations`** stores contexts used when observed counts are derived for **`observation_mode="admitted_at_some_point"`**.

# %%
obs_ed_current_by_service = {service: test_visits_df for service in specialties}
builder.add_distributions_from_service_dict(
    "ed_current_beds",
    prob_dist_by_service=ed_current_by_service,
    model_name=model_name,
)
builder.add_distribution_observations(
    "ed_current_beds",
    observations_by_service=obs_ed_current_by_service,
    prediction_window=prediction_window,
)

# %% [markdown]
# ### 2g. ED yet-to-arrive bed demand (distribution, C)
#
# Same pattern for **`ed_yta_beds`**: predicted PMFs from section 1, then **`observations_by_service`** with one **inpatient admissions** dataframe per specialty (from **`arrivals_by_service`** in 2b, or the full test inpatient extract as fallback). That matches **`observation_mode="arrived_in_window"`**: when **`count_observed`** is wired for distribution evaluation, those frames are passed as the generic **`visits`** argument (not **`ed_visits`**), counting **`arrival_datetime`** in `(moment, moment + prediction_window]` on rows that are already admitted inpatients.

# %%
obs_ed_yta_by_service = {
    service: arrivals_by_service.get(service, test_inpatient_arrivals_df)
    for service in specialties
}
builder.add_distributions_from_service_dict(
    "ed_yta_beds",
    prob_dist_by_service=ed_yta_by_service,
    model_name=model_name,
)
builder.add_distribution_observations(
    "ed_yta_beds",
    observations_by_service=obs_ed_yta_by_service,
    prediction_window=prediction_window,
)

# %% [markdown]
# ### 2h. ED yet-to-arrive arrival deltas
#
# **`add_arrival_deltas`** takes snapshot dates, the prediction window, and optional **fitted predictors**. Because **`yta_model_by_spec`** has one weight entry per service, pass **`filter_keys_by_service`** so each service’s baseline matches the correct fitted profile.

# %%
builder.add_arrival_deltas(
    "ed_yta_arrival_rates",
    arrivals_by_service=obs_ed_yta_by_service,
    snapshot_dates=test_snapshot_dates,
    prediction_window=prediction_window,
    yta_time_interval=yta_time_interval,
    predictors_by_service={s: yta_model_by_spec for s in specialties},
    filter_keys_by_service={s: s for s in specialties},
)

# %% [markdown]
# ### 2i. Build `EvaluationInputs`
#
# **`build()`** checks that **`flow_selection`** and **`prediction_times`** are set, then returns the immutable object consumed by **`run_evaluation`**. The printout lists each target for a quick sanity check before the (longer) evaluation run.

# %%
inputs = builder.build()

print(f"Targets: {len(evaluation_targets)}")
for t in evaluation_targets:
    print(f"  {t.name}: {t.evaluation_mode} (observation_mode={t.observation_mode})")
print(f"Prediction times: {prediction_times}")
# Out:
# Targets: 5
#   admission_classifier_model: classifier_model_diagnostics (observation_mode=admitted_at_some_point)
#   admission_classifier_prob: classifier_probability_quality (observation_mode=admitted_at_some_point)
#   ed_current_epudd: distribution (observation_mode=admitted_at_some_point)
#   ed_yta_epudd: distribution (observation_mode=arrived_in_window)
#   ed_yta_arrival_deltas: arrival_deltas (observation_mode=arrived_in_window)
# Prediction times: [(6, 0), (9, 30), (12, 0), (15, 30), (22, 0)]

# %% [markdown]
# ## 3. Run evaluation
#
# `run_evaluation` creates `run_dir / evaluation_run.yaml`, `run_dir / scalars.json`, and subfolders (`classifiers/`, `distributions/`, `arrivals/`, …) when those modes produce output. It returns `run_dir`, `scalars_path`, `manifest_path`, and `n_targets`.

# %%
from datetime import datetime

from patientflow.evaluate.runner import run_evaluation

run_name = f"notebook4d_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
out = run_evaluation(Path("eval-output"), inputs, run_name=run_name)
out
# Out:
# Predicted classification (not admitted, admitted):  [1660  958]
# Predicted classification (not admitted, admitted):  [2791 1358]
# Predicted classification (not admitted, admitted):  [4923 2311]
# Predicted classification (not admitted, admitted):  [5739 2784]
# Predicted classification (not admitted, admitted):  [4296 2314]
# {'run_dir': PosixPath('eval-output/notebook4d_20260515_102340'),
#  'scalars_path': PosixPath('eval-output/notebook4d_20260515_102340/scalars.json'),
#  'n_targets': 5}

# %% [markdown]
# ## 4. Review outputs
#
# Scalar rows are stored under the `evaluation_rows` key (with optional `_service_summary` for inactive-service bookkeeping). Below we print the run layout and show the first rows of the scalar table.

# %%
import json

from IPython.display import display

run_dir = out["run_dir"]
scalars_path = out["scalars_path"]

print("Run directory:", run_dir)
print("Scalars path:", scalars_path)

print("\nDirectory structure (depth <= 2):")
for p in sorted(run_dir.rglob("*")):
    depth = len(p.relative_to(run_dir).parts)
    if depth <= 2:
        indent = "  " * (depth - 1)
        print(f"{indent}{p.name}{'/' if p.is_dir() else ''}")

payload = json.loads(scalars_path.read_text(encoding="utf-8"))
rows = payload.get("evaluation_rows") or []
scalars_df = pd.DataFrame(rows)
print(f"\nScalar rows: {len(scalars_df)}")
if "_service_summary" in payload:
    print("_service_summary keys:", list(payload["_service_summary"].keys()))

base_cols = [
    c
    for c in [
        "evaluation_mode",
        "flow",
        "service",
        "component",
        "prediction_time",
        "charts_generated",
        "skip_reason",
    ]
    if c in scalars_df.columns
]
display(scalars_df[base_cols].head(16))
# Out:
# Run directory: eval-output/notebook4d_20260515_102340
# Scalars path: eval-output/notebook4d_20260515_102340/scalars.json
#
# Directory structure (depth <= 2):
# arrivals/
#   ed_yta_arrival_rates/
# classifiers/
#   ed_admissions_cls/
# evaluation_run.yaml
# distributions/
#   ed_current_beds/
#   ed_yta_beds/
# scalars.json
#
# Scalar rows: 70
# _service_summary keys: ['by_slice']
#                    evaluation_mode               flow   service  \
# 0     classifier_model_diagnostics  ed_admissions_cls     _all_
# 1     classifier_model_diagnostics  ed_admissions_cls     _all_
# 2     classifier_model_diagnostics  ed_admissions_cls     _all_
# 3     classifier_model_diagnostics  ed_admissions_cls     _all_
# 4     classifier_model_diagnostics  ed_admissions_cls     _all_
# 5   classifier_probability_quality  ed_admissions_cls     _all_
# 6   classifier_probability_quality  ed_admissions_cls     _all_
# 7   classifier_probability_quality  ed_admissions_cls     _all_
# ...

# %% [markdown]
# ## Summary
#
# 1. Built **service-level prediction dicts** with a **per-clock** nested layout for EPUDD (`get_model_key` as the middle key).
# 2. Declared **`EvaluationTarget` instances** and wired **`EvaluationInputsBuilder`** with one **`flow_selection`**, matching `flow_name` keys on targets to builder registrations.
# 3. Ran **`run_evaluation`** to emit plots and **`scalars.json`**.
# 4. Loaded **`evaluation_rows`** for a tabular overview.
#
# For a wider evaluation matrix (departures, non-ED yet-to-arrive, survival, and default `flow_name="main"` wiring), start from **`get_default_evaluation_targets()`** and align builder `flow_name` keys with that registry, or pass a filtered list via **`with_evaluation_targets`**.
